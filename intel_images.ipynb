# %% [markdown]
# <h1 style="text-align:center">Intel Image Classification

# %% [markdown]
# <div style="text-align:justify">
# In this project, we will be working on Intel images i.e. images of buildings, forest, street, etc. We will built a convolutional neural network and train it on this images. This is a multi class classification problem and we will use Keras.

# %%
# Load the Drive helper and mount
from google.colab import drive

# This will prompt for authorization.
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# <div style="text-align:justify">
# First we will mount our google drive on colab so that we can use the dataset directly from our drive. For this you first need to upload the data on your drive and then mount the drive on colab.

# %%
# After executing the cell above, Drive files will be present in "/content/drive/My Drive".
# !ls "/content/drive/My Drive/Dataset"
# Out:
# 'Intel Image Dataset'

# %% [markdown]
# <div style="text-align:justify">
# After mounting our drive we will locate the folder where our data is stored to use it in our colab notebook. Here we will see all the folders I have in my drive and 'Intel Image Dataset' contains the images that we will work on.

# %%
# Important imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.image import imread
import cv2
import random
from os import listdir
from sklearn.preprocessing import  LabelBinarizer
from keras.preprocessing import image
from tensorflow.keras.utils import img_to_array
from tensorflow.keras.utils import array_to_img
from keras.optimizers import Adam
from PIL import Image
from keras.models import Sequential
from tensorflow.keras.layers import BatchNormalization
from keras.layers import Conv2D, MaxPooling2D, Activation, Flatten, Dropout, Dense, LeakyReLU
from sklearn.model_selection import train_test_split

# %% [markdown]
# We will start by importing some required libraries.

# %%
# Listing directory
# !ls "/content/drive/My Drive/Dataset/Intel Image Dataset"
# Out:
# buildings  forest  glacier  mountain  sea  street

# %% [markdown]
# We will check for folders of class images.

# %%
# Plotting 25 images to check dataset
plt.figure(figsize=(11,11))
path = "/content/drive/My Drive/Dataset/Intel Image Dataset/mountain"
for i in range(1,26):
    plt.subplot(5,5,i)
    plt.tight_layout()
    rand_img = imread(path +'/'+ random.choice(sorted(listdir(path))))
    plt.imshow(rand_img)
    plt.title('mountain')
    plt.xlabel(rand_img.shape[1], fontsize = 10)
    plt.ylabel(rand_img.shape[0], fontsize = 10)

# %% [markdown]
# Let's visualize some of the mountain images that we will be working on. Also we will observe x and y dimensions of the image.

# %%
# Setting root directory path and creating empty list
dir = "/content/drive/My Drive/Dataset/Intel Image Dataset"
root_dir = listdir(dir)
image_list, label_list = [], []
print(root_dir)
# Out:
# ['mountain', 'forest', 'glacier', 'sea', 'street', 'buildings']

# %% [markdown]
# Setting the root directory for the dataset and storing all the folders name of the dataset. We will also create 2 empty list for image and lables.

# %%
# Reading and converting image to numpy array
for directory in root_dir:
  for files in listdir(f"{dir}/{directory}"):
    image_path = f"{dir}/{directory}/{files}"
    image = Image.open(image_path)
    image = image.resize((150,150)) # All images does not have same dimension
    image = img_to_array(image)
    image_list.append(image)
    label_list.append(directory)

# %% [markdown]
# <div style="text-align:justify">
# Next we need to resize images as some of the images don't have same dimensions. So, we will read and resize all the images. Then we will convert it into array and appending the list created above with the image and its label.

# %%
# Visualize the number of classes count
label_counts = pd.DataFrame(label_list).value_counts()
label_counts
# Out:
# glacier      553
# mountain     525
# sea          510
# street       501
# forest       474
# buildings    437
# dtype: int64

# %% [markdown]
# Checking for images per class.

# %%
# Checking count of classes
num_classes = len(label_counts)
num_classes
# Out:
# 6

# %% [markdown]
# Storing the number of classes which will be used further in model architecture.

# %%
# Checking x data shape
np.array(image_list).shape
# Out:
# (3000, 150, 150, 3)

# %% [markdown]
# Check the shape of the x data for input layer of model architecture.

# %%
# Checking y data shape
label_list = np.array(label_list)
label_list.shape
# Out:
# (3000,)

# %% [markdown]
# Checking the number of labels in y data which should be equal to total number of images.

# %%
# Splitting dataset into test and train
x_train, x_test, y_train, y_test = train_test_split(image_list, label_list, test_size=0.2, random_state = None)

# %% [markdown]
# Now we will split our dataset into testing and training using train_test_split() from sklearn.

# %%
# Normalize and reshape data
x_train = np.array(x_train, dtype=np.float16) / 225.0
x_test = np.array(x_test, dtype=np.float16) / 225.0
x_train = x_train.reshape( -1, 150,150,3)
x_test = x_test.reshape( -1, 150,150,3)

# %% [markdown]
# Next we will normalize the images by dividing them with 255 and we will also reshape x_train and x_test data.

# %%
# Binarizing labels
lb = LabelBinarizer()
y_train = lb.fit_transform(y_train)
y_test = lb.fit_transform(y_test)
print(lb.classes_)
# Out:
# ['buildings' 'forest' 'glacier' 'mountain' 'sea' 'street']

# %% [markdown]
# Here we will use label binarizer to one hot encode our y data. We will also print the sequence of the classes.

# %%
# Splitting the training data set into training and validation data sets
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size = 0.2)

# %% [markdown]
# Now we will split the training data to validation and training data.

# %%
# Creating model architecture
model = Sequential([

        Conv2D(16, kernel_size = (3,3), input_shape = (150,150,3)),
        BatchNormalization(),
        LeakyReLU(),

        Conv2D(32, kernel_size = (3,3)),
        BatchNormalization(),
        LeakyReLU(),
        MaxPooling2D(5,5),

        Conv2D(64, kernel_size = (3,3)),
        BatchNormalization(),
        LeakyReLU(),

        Conv2D(128, kernel_size = (3,3)),
        BatchNormalization(),
        LeakyReLU(),
        MaxPooling2D(5,5),

        Flatten(),

        Dense(64),
        Dropout(rate = 0.2),
        BatchNormalization(),
        LeakyReLU(),

        Dense(32),
        Dropout(rate = 0.2),
        BatchNormalization(),
        LeakyReLU(),

        Dense(16),
        Dropout(rate = 0.2),
        BatchNormalization(),
        LeakyReLU(1),

        Dense(6, activation = 'softmax')
        ])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 148, 148, 16)      448
#
#  batch_normalization (BatchN  (None, 148, 148, 16)     64
#  ormalization)
#
#  leaky_re_lu (LeakyReLU)     (None, 148, 148, 16)      0
#
#  conv2d_1 (Conv2D)           (None, 146, 146, 32)      4640
#
#  batch_normalization_1 (Batc  (None, 146, 146, 32)     128
#  hNormalization)
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 146, 146, 32)      0
#
#  max_pooling2d (MaxPooling2D  (None, 29, 29, 32)       0
#  )
#
#  conv2d_2 (Conv2D)           (None, 27, 27, 64)        18496
#
#  batch_normalization_2 (Batc  (None, 27, 27, 64)       256
#  hNormalization)
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 27, 27, 64)        0
#
#  conv2d_3 (Conv2D)           (None, 25, 25, 128)       73856
#
#  batch_normalization_3 (Batc  (None, 25, 25, 128)      512
#  hNormalization)
#
#  leaky_re_lu_3 (LeakyReLU)   (None, 25, 25, 128)       0
#
#  max_pooling2d_1 (MaxPooling  (None, 5, 5, 128)        0
#  2D)
#
#  flatten (Flatten)           (None, 3200)              0
#
#  dense (Dense)               (None, 64)                204864
#
#  dropout (Dropout)           (None, 64)                0
#
#  batch_normalization_4 (Batc  (None, 64)               256
#  hNormalization)
#
#  leaky_re_lu_4 (LeakyReLU)   (None, 64)                0
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  batch_normalization_5 (Batc  (None, 32)               128
#  hNormalization)
#
#  leaky_re_lu_5 (LeakyReLU)   (None, 32)                0
#
#  dense_2 (Dense)             (None, 16)                528
#
#  dropout_2 (Dropout)         (None, 16)                0
#
#  batch_normalization_6 (Batc  (None, 16)               64
#  hNormalization)
#
#  leaky_re_lu_6 (LeakyReLU)   (None, 16)                0
#
#  dense_3 (Dense)             (None, 6)                 102
#
# =================================================================
# Total params: 306,422
# Trainable params: 305,718
# Non-trainable params: 704
# _________________________________________________________________

# %% [markdown]
# <div style="text-align:justify">
# Now we will create a network architecture for the model. We have used different types of layers according to their features namely BatchNormalization (Batch normalization is a technique for training very deep neural networks that standardizes the inputs to a layer for each mini-batch), LeakyRelu (The Leaky ReLU modifies the function to allow small negative values when the input is less than zero), Conv_2d (It is used to create a convolutional kernel that is convolved with the input layer to produce the output tensor), max_pooling2d (It is a downsampling technique which takes out the maximum value over the window defined by poolsize), flatten (It flattens the input and creates a 1D output), Dense (Dense layer produce the output as the dot product of input and kernel). In the last layer we will use softmax as the activation function because it is a multi class classification problem.

# %%
# Compiling model
model.compile(loss = 'categorical_crossentropy', optimizer = Adam(0.0005),metrics=['accuracy'])

# %% [markdown]
# For compiling the model we need to pass 3 parameters namely loss, optimizer and metrics. Here we will use loss as categorical_crossentropy, optimizer as Adam and metrics as accuracy.

# %%
# Training the model
epochs = 70
batch_size = 128
history = model.fit(x_train, y_train, batch_size = batch_size, epochs = epochs, validation_data = (x_val, y_val))
# Out:
# Epoch 1/70
# 15/15 [==============================] - 16s 261ms/step - loss: 1.6473 - accuracy: 0.3917 - val_loss: 1.7285 - val_accuracy: 0.2583
# Epoch 2/70
# 15/15 [==============================] - 2s 147ms/step - loss: 1.2679 - accuracy: 0.5453 - val_loss: 1.8055 - val_accuracy: 0.2667
# Epoch 3/70
# 15/15 [==============================] - 2s 148ms/step - loss: 1.1286 - accuracy: 0.6021 - val_loss: 1.8564 - val_accuracy: 0.1875
# Epoch 4/70
# 15/15 [==============================] - 2s 149ms/step - loss: 1.0485 - accuracy: 0.6385 - val_loss: 1.9150 - val_accuracy: 0.1896
# Epoch 5/70
# 15/15 [==============================] - 2s 147ms/step - loss: 0.9543 - accuracy: 0.6823 - val_loss: 2.0055 - val_accuracy: 0.1896
# Epoch 6/70
# 15/15 [==============================] - 2s 151ms/step - loss: 0.8594 - accuracy: 0.7224 - val_loss: 1.9931 - val_accuracy: 0.2021
# Epoch 7/70
# 15/15 [==============================] - 2s 147ms/step - loss: 0.7715 - accuracy: 0.7620 - val_loss: 2.1632 - val_accuracy: 0.1896
# Epoch 8/70
# 15/15 [==============================] - 2s 150ms/step - loss: 0.7256 - accuracy: 0.7844 - val_loss: 2.1546 - val_accuracy: 0.1875
# Epoch 9/70
# 15/15 [==============================] - 2s 139ms/step - loss: 0.6582 - accuracy: 0.8120 - val_loss: 2.2923 - val_accuracy: 0.1875
# Epoch 10/70
# 15/15 [==============================] - 2s 141ms/step - loss: 0.6073 - accuracy: 0.8427 - val_loss: 2.0197 - val_accuracy: 0.2313
# Epoch 11/70
# 15/15 [==============================] - 2s 148ms/step - loss: 0.5177 - accuracy: 0.8729 - val_loss: 2.0934 - val_accuracy: 0.1875
# Epoch 12/70
# 15/15 [==============================] - 2s 156ms/step - loss: 0.4836 - accuracy: 0.8839 - val_loss: 2.2964 - val_accuracy: 0.1875
# Epoch 13/70
# 15/15 [==============================] - 2s 157ms/step - loss: 0.4621 - accuracy: 0.8958 - val_loss: 1.8639 - val_accuracy: 0.2458
# Epoch 14/70
# 15/15 [==============================] - 2s 148ms/step - loss: 0.4055 - accuracy: 0.9125 - val_loss: 2.0270 - val_accuracy: 0.2521
# Epoch 15/70
# 15/15 [==============================] - 2s 139ms/step - loss: 0.3669 - accuracy: 0.9333 - val_loss: 1.9399 - val_accuracy: 0.2458
# Epoch 16/70
# 15/15 [==============================] - 2s 148ms/step - loss: 0.3236 - accuracy: 0.9474 - val_loss: 2.0947 - val_accuracy: 0.2208
# Epoch 17/70
# 15/15 [==============================] - 2s 140ms/step - loss: 0.3018 - accuracy: 0.9563 - val_loss: 1.6824 - val_accuracy: 0.3729
# Epoch 18/70
# 15/15 [==============================] - 2s 154ms/step - loss: 0.2753 - accuracy: 0.9604 - val_loss: 1.6800 - val_accuracy: 0.2896
# Epoch 19/70
# 15/15 [==============================] - 2s 158ms/step - loss: 0.2611 - accuracy: 0.9599 - val_loss: 1.7859 - val_accuracy: 0.3187
# Epoch 20/70
# 15/15 [==============================] - 2s 142ms/step - loss: 0.2216 - accuracy: 0.9740 - val_loss: 1.5926 - val_accuracy: 0.3875
# Epoch 21/70
# 15/15 [==============================] - 2s 149ms/step - loss: 0.2042 - accuracy: 0.9828 - val_loss: 1.8928 - val_accuracy: 0.3125
# Epoch 22/70
# 15/15 [==============================] - 2s 149ms/step - loss: 0.1907 - accuracy: 0.9797 - val_loss: 1.7000 - val_accuracy: 0.3688
# Epoch 23/70
# 15/15 [==============================] - 2s 149ms/step - loss: 0.1789 - accuracy: 0.9833 - val_loss: 1.7384 - val_accuracy: 0.3500
# Epoch 24/70
# 15/15 [==============================] - 2s 157ms/step - loss: 0.1949 - accuracy: 0.9714 - val_loss: 1.0813 - val_accuracy: 0.6062
# Epoch 25/70
# 15/15 [==============================] - 2s 145ms/step - loss: 0.1568 - accuracy: 0.9870 - val_loss: 1.2915 - val_accuracy: 0.5458
# Epoch 26/70
# 15/15 [==============================] - 2s 140ms/step - loss: 0.1402 - accuracy: 0.9932 - val_loss: 0.9281 - val_accuracy: 0.6687
# Epoch 27/70
# 15/15 [==============================] - 2s 141ms/step - loss: 0.1323 - accuracy: 0.9911 - val_loss: 0.9981 - val_accuracy: 0.6250
# Epoch 28/70
# 15/15 [==============================] - 2s 149ms/step - loss: 0.1215 - accuracy: 0.9937 - val_loss: 0.9511 - val_accuracy: 0.6729
# Epoch 29/70
# 15/15 [==============================] - 2s 148ms/step - loss: 0.1212 - accuracy: 0.9964 - val_loss: 0.9032 - val_accuracy: 0.6792
# Epoch 30/70
# 15/15 [==============================] - 2s 153ms/step - loss: 0.1108 - accuracy: 0.9948 - val_loss: 0.8082 - val_accuracy: 0.7354
# Epoch 31/70
# 15/15 [==============================] - 2s 157ms/step - loss: 0.1075 - accuracy: 0.9917 - val_loss: 0.9060 - val_accuracy: 0.6896
# Epoch 32/70
# 15/15 [==============================] - 2s 141ms/step - loss: 0.0980 - accuracy: 0.9958 - val_loss: 0.8157 - val_accuracy: 0.7292
# Epoch 33/70
# 15/15 [==============================] - 2s 141ms/step - loss: 0.0980 - accuracy: 0.9953 - val_loss: 0.7740 - val_accuracy: 0.7333
# Epoch 34/70
# 15/15 [==============================] - 2s 143ms/step - loss: 0.0912 - accuracy: 0.9958 - val_loss: 0.8479 - val_accuracy: 0.7104
# Epoch 35/70
# 15/15 [==============================] - 2s 149ms/step - loss: 0.0820 - accuracy: 0.9974 - val_loss: 0.7855 - val_accuracy: 0.7417
# Epoch 36/70
# 15/15 [==============================] - 2s 155ms/step - loss: 0.0855 - accuracy: 0.9932 - val_loss: 0.8183 - val_accuracy: 0.7333
# Epoch 37/70
# 15/15 [==============================] - 2s 156ms/step - loss: 0.0841 - accuracy: 0.9953 - val_loss: 0.7528 - val_accuracy: 0.7500
# Epoch 38/70
# 15/15 [==============================] - 2s 151ms/step - loss: 0.0871 - accuracy: 0.9953 - val_loss: 0.8465 - val_accuracy: 0.7333
# Epoch 39/70
# 15/15 [==============================] - 2s 143ms/step - loss: 0.0723 - accuracy: 0.9964 - val_loss: 0.8937 - val_accuracy: 0.7396
# Epoch 40/70
# 15/15 [==============================] - 2s 143ms/step - loss: 0.0749 - accuracy: 0.9974 - val_loss: 0.6901 - val_accuracy: 0.7771
# Epoch 41/70
# 15/15 [==============================] - 2s 142ms/step - loss: 0.0723 - accuracy: 0.9948 - val_loss: 0.7694 - val_accuracy: 0.7604
# Epoch 42/70
# 15/15 [==============================] - 2s 155ms/step - loss: 0.0639 - accuracy: 0.9990 - val_loss: 0.7470 - val_accuracy: 0.7646
# Epoch 43/70
# 15/15 [==============================] - 2s 152ms/step - loss: 0.0605 - accuracy: 0.9984 - val_loss: 0.7239 - val_accuracy: 0.7792
# Epoch 44/70
# 15/15 [==============================] - 2s 142ms/step - loss: 0.0634 - accuracy: 0.9974 - val_loss: 0.7538 - val_accuracy: 0.7667
# Epoch 45/70
# 15/15 [==============================] - 2s 142ms/step - loss: 0.0636 - accuracy: 0.9958 - val_loss: 0.8037 - val_accuracy: 0.7646
# Epoch 46/70
# 15/15 [==============================] - 2s 143ms/step - loss: 0.0587 - accuracy: 0.9979 - val_loss: 0.8611 - val_accuracy: 0.7458
# Epoch 47/70
# 15/15 [==============================] - 2s 144ms/step - loss: 0.0586 - accuracy: 0.9974 - val_loss: 0.8095 - val_accuracy: 0.7396
# Epoch 48/70
# 15/15 [==============================] - 2s 153ms/step - loss: 0.0606 - accuracy: 0.9974 - val_loss: 0.9771 - val_accuracy: 0.7312
# Epoch 49/70
# 15/15 [==============================] - 2s 162ms/step - loss: 0.0531 - accuracy: 0.9958 - val_loss: 0.7359 - val_accuracy: 0.7750
# Epoch 50/70
# 15/15 [==============================] - 2s 141ms/step - loss: 0.0519 - accuracy: 0.9979 - val_loss: 0.8480 - val_accuracy: 0.7563
# Epoch 51/70
# 15/15 [==============================] - 2s 141ms/step - loss: 0.0482 - accuracy: 1.0000 - val_loss: 0.7305 - val_accuracy: 0.7750
# Epoch 52/70
# 15/15 [==============================] - 2s 141ms/step - loss: 0.0480 - accuracy: 0.9984 - val_loss: 0.7151 - val_accuracy: 0.7771
# Epoch 53/70
# 15/15 [==============================] - 2s 151ms/step - loss: 0.0456 - accuracy: 0.9995 - val_loss: 0.8044 - val_accuracy: 0.7333
# Epoch 54/70
# 15/15 [==============================] - 2s 155ms/step - loss: 0.0433 - accuracy: 0.9984 - val_loss: 0.8037 - val_accuracy: 0.7604
# Epoch 55/70
# 15/15 [==============================] - 2s 161ms/step - loss: 0.0379 - accuracy: 0.9990 - val_loss: 0.8372 - val_accuracy: 0.7542
# Epoch 56/70
# 15/15 [==============================] - 2s 151ms/step - loss: 0.0376 - accuracy: 1.0000 - val_loss: 0.7919 - val_accuracy: 0.7604
# Epoch 57/70
# 15/15 [==============================] - 2s 143ms/step - loss: 0.0365 - accuracy: 0.9990 - val_loss: 0.8179 - val_accuracy: 0.7625
# Epoch 58/70
# 15/15 [==============================] - 2s 144ms/step - loss: 0.0337 - accuracy: 0.9995 - val_loss: 0.7010 - val_accuracy: 0.7771
# Epoch 59/70
# 15/15 [==============================] - 2s 150ms/step - loss: 0.0380 - accuracy: 0.9979 - val_loss: 0.7836 - val_accuracy: 0.7792
# Epoch 60/70
# 15/15 [==============================] - 2s 153ms/step - loss: 0.0414 - accuracy: 0.9979 - val_loss: 0.7972 - val_accuracy: 0.7437
# Epoch 61/70
# 15/15 [==============================] - 2s 160ms/step - loss: 0.0360 - accuracy: 0.9995 - val_loss: 0.8476 - val_accuracy: 0.7521
# Epoch 62/70
# 15/15 [==============================] - 2s 142ms/step - loss: 0.0360 - accuracy: 0.9984 - val_loss: 0.7772 - val_accuracy: 0.7937
# Epoch 63/70
# 15/15 [==============================] - 2s 151ms/step - loss: 0.0333 - accuracy: 0.9995 - val_loss: 0.8760 - val_accuracy: 0.7500
# Epoch 64/70
# 15/15 [==============================] - 2s 143ms/step - loss: 0.0334 - accuracy: 0.9995 - val_loss: 0.7686 - val_accuracy: 0.7563
# Epoch 65/70
# 15/15 [==============================] - 2s 142ms/step - loss: 0.0306 - accuracy: 1.0000 - val_loss: 0.7468 - val_accuracy: 0.7667
# Epoch 66/70
# 15/15 [==============================] - 2s 158ms/step - loss: 0.0294 - accuracy: 0.9990 - val_loss: 0.7565 - val_accuracy: 0.7729
# Epoch 67/70
# 15/15 [==============================] - 2s 160ms/step - loss: 0.0315 - accuracy: 0.9990 - val_loss: 0.7752 - val_accuracy: 0.7729
# Epoch 68/70
# 15/15 [==============================] - 2s 151ms/step - loss: 0.0278 - accuracy: 0.9995 - val_loss: 0.7739 - val_accuracy: 0.7500
# Epoch 69/70
# 15/15 [==============================] - 2s 150ms/step - loss: 0.0275 - accuracy: 0.9995 - val_loss: 0.7687 - val_accuracy: 0.7750
# Epoch 70/70
# 15/15 [==============================] - 2s 149ms/step - loss: 0.0263 - accuracy: 0.9995 - val_loss: 0.8197 - val_accuracy: 0.7646

# %% [markdown]
# <div style="text-align:justify">
# Fitting the model with the data and finding out the accuracy at each epoch to see how our model is learning. Now we will train our model on 70 epochs and a batch size of 128. You can try using more number of epochs to increase accuracy. During each epochs we can see how the model is performing by viewing the training and validation accuracy.

# %%
# Saving model
model.save("/content/drive/My Drive/intel_image.h5")

# %% [markdown]
# We will save the model using model.save() to use it later for prediction.

# %%
#Plot the training history
plt.figure(figsize=(12, 5))
plt.plot(history.history['accuracy'], color='r')
plt.plot(history.history['val_accuracy'], color='b')
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['train', 'val'])
plt.show()

# %% [markdown]
# Next we will plot the accuracy of the model for the training history.

# %%
#Plot the loss history
plt.figure(figsize=(12, 5))
plt.plot(history.history['loss'], color='r')
plt.plot(history.history['val_loss'], color='b')
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['train', 'val'])
plt.show()

# %% [markdown]
# Next we will plot the loss of the model for the training history.

# %%
# Calculating test accuracy
scores = model.evaluate(x_test, y_test)
print(f"Test Accuracy: {scores[1]*100}")
# Out:
# 19/19 [==============================] - 1s 26ms/step - loss: 0.9542 - accuracy: 0.7267
# Test Accuracy: 72.66666889190674

# %% [markdown]
# Evaluating the model to know the accuracy of the model on the test data.

# %%
# Storing model predictions
y_pred = model.predict(x_test)
# Out:
# 19/19 [==============================] - 0s 15ms/step

# %% [markdown]
# Generating predictions for test data and storing them into y_pred.

# %%
# Plotting image to compare
img = array_to_img(x_test[1])
img
# Out:
# <PIL.Image.Image image mode=RGB size=150x150 at 0x7F6EEE0959C0>

# %% [markdown]
# Visualizing an image to be predicted in further steps.

# %%
# Finding max value from predition list and comaparing original value vs predicted
labels = lb.classes_
print(labels)
print("Originally : ",labels[np.argmax(y_test[1])])
print("Predicted : ",labels[np.argmax(y_pred[1])])
# Out:
# ['buildings' 'forest' 'glacier' 'mountain' 'sea' 'street']
# Originally :  buildings
# Predicted :  buildings

# %% [markdown]
# <div style="text-align:justify">
# Now, we will create list of labels using object of label binarizer. We will print that list and finally we will print out the prediction and the original label of the image we visualized above using argmax().

# %% [markdown]
# ## Conclusion:

# %% [markdown]
# <div style="text-align:justify">
# In this project we saw how we can create a CNN using different layers. Normalizing is an important step when working with any type of dataset. We will use this model to predict the class of the image supplied to the model.
